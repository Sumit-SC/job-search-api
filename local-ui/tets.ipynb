# %%
pip install -U python-jobspy
# Out:
# Collecting python-jobspy
#   Using cached python_jobspy-1.1.82-py3-none-any.whl.metadata (10 kB)
# Collecting NUMPY==1.26.3 (from python-jobspy)
#   Using cached numpy-1.26.3-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.2 (from python-jobspy)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting markdownify<0.14.0,>=0.13.1 (from python-jobspy)
#   Using cached markdownify-0.13.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting pandas<3.0.0,>=2.1.0 (from python-jobspy)
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting pydantic<3.0.0,>=2.3.0 (from python-jobspy)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting regex<2025.0.0,>=2024.4.28 (from python-jobspy)
#   Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting requests<3.0.0,>=2.31.0 (from python-jobspy)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tls-client<2.0.0,>=1.0.1 (from python-jobspy)
#   Using cached tls_client-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4<5.0.0,>=4.12.2->python-jobspy)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sumit\appdata\roaming\python\python311\site-packages (from beautifulsoup4<5.0.0,>=4.12.2->python-jobspy) (4.15.0)
# Requirement already satisfied: six<2,>=1.15 in c:\users\sumit\appdata\roaming\python\python311\site-packages (from markdownify<0.14.0,>=0.13.1->python-jobspy) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sumit\appdata\roaming\python\python311\site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=2.1.0->python-jobspy)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.1.0->python-jobspy)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.3.0->python-jobspy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.3.0->python-jobspy)
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.3.0->python-jobspy)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Using cached python_jobspy-1.1.82-py3-none-any.whl (52 kB)
# Using cached numpy-1.26.3-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached markdownify-0.13.1-py3-none-any.whl (10 kB)
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached tls_client-1.0.1-py3-none-any.whl (41.3 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Installing collected packages: tls-client, pytz, urllib3, tzdata, typing-inspection, soupsieve, regex, pydantic-core, NUMPY, idna, charset_normalizer, certifi, annotated-types, requests, pydantic, pandas, beautifulsoup4, markdownify, python-jobspy
# Successfully installed NUMPY-1.26.3 annotated-types-0.7.0 beautifulsoup4-4.14.3 certifi-2026.1.4 charset_normalizer-3.4.4 idna-3.11 markdownify-0.13.1 pandas-2.3.3 pydantic-2.12.5 pydantic-core-2.41.5 python-jobspy-1.1.82 pytz-2025.2 regex-2024.11.6 requests-2.32.5 soupsieve-2.8.3 tls-client-1.0.1 typing-inspection-0.4.2 tzdata-2025.3 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "google"], # "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="data analyst",
    google_search_term="software engineer jobs near San Francisco, CA since yesterday",
    location="San Francisco, CA",
    results_wanted=10,
    hours_old=72,
    country_indeed='india',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# Found 10 jobs
#               id      site                                        job_url  \
# 0  li-4330734459  linkedin  https://www.linkedin.com/jobs/view/4330734459
# 1  li-4373344286  linkedin  https://www.linkedin.com/jobs/view/4373344286
# 2  li-4366629697  linkedin  https://www.linkedin.com/jobs/view/4366629697
# 3  li-4321559093  linkedin  https://www.linkedin.com/jobs/view/4321559093
# 4  li-4373396835  linkedin  https://www.linkedin.com/jobs/view/4373396835
#
#   job_url_direct                            title                 company  \
# 0           None           eCommerce Data Analyst                 Corsair
# 1           None           Associate Data Analyst    LatentView Analytics
# 2           None                     Data Analyst             HockeyStack
# 3           None  Product Data Analyst, Servicing           Upgrade, Inc.
# 4           None            Business-Data Analyst  Heyer Expectations LLC
#
#             location date_posted job_type salary_source  ...  \
# 0       Milpitas, CA  2026-02-19     None          None  ...
# 1       San Jose, CA  2026-02-18     None          None  ...
# 2  San Francisco, CA  2026-02-18     None          None  ...
# 3  San Francisco, CA  2026-02-18     None          None  ...
# 4        Oakland, CA  2026-02-18     None          None  ...
#
#   company_addresses company_num_employees company_revenue company_description  \
# 0              None                  None            None                None
# 1              None                  None            None                None
# 2              None                  None            None                None
# 3              None                  None            None                None
# 4              None                  None            None                None
#
#    skills experience_range company_rating company_reviews_count vacancy_count  \
# 0    None             None           None                  None          None
# 1    None             None           None                  None          None
# 2    None             None           None                  None          None
# 3    None             None           None                  None          None
# 4    None             None           None                  None          None
#
#   work_from_home_type
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 34 columns]
